# %% [markdown]
# # 11.4 生成增强本节涵盖：上下文注入, 引用生成, 幻觉检测

# %%
print('=== Context Injection ===')print('Simplest RAG: prepend retrieved documents to the prompt')print()print('Template:')print('  """Context:')print('  [1] Retrieved document 1...')print('  [2] Retrieved document 2...')print('  ')print('  Question: {user_question}')print('  Answer based on the context above:"""')print()print('=== Citation Generation ===')print('Train model to cite sources in its response')print('Format: "According to [1], the answer is... Additionally, [2] shows..."')print('Benefits: verifiable, trustworthy, traceable')print()print('=== Hallucination Detection ===')print('Methods:')print('  1. Entropy-based: high entropy = uncertain = likely hallucination')print('  2. Consistency check: sample multiple responses, check agreement')print('  3. Attribution: verify claims against retrieved documents')print('  4. NLI-based: check if response is entailed by context')print()print('Production approach:')print('  - Generate response with citations')print('  - Verify each cited claim against source document')print('  - Flag unverifiable claims as potential hallucinations')
