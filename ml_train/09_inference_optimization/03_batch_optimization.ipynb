# %% [markdown]
# # 9.3 批处理优化本节涵盖：Continuous Batching, Dynamic Batching

# %%
import randomprint('=== Static Batching ===')print('Wait for all sequences in batch to complete before processing next batch')print()print('Timeline (4 requests, different lengths):')print('  Req1: ████████ (8 tokens)')print('  Req2: ████████████████ (16 tokens)')print('  Req3: ████ (4 tokens) -> idle for 12 steps!')print('  Req4: ████████████ (12 tokens)')print('  GPU utilization: ~60% (lots of padding and idle time)')print()print('=== Continuous Batching (vLLM) ===')print('Insert new requests as soon as old ones complete')print()print('Timeline:')print('  Req1: ████████')print('  Req2: ████████████████')print('  Req3: ████')print('  Req5:         ████████████ (starts when Req3 finishes)')print('  Req4: ████████████')print('  Req6:                 ████ (starts when Req1 finishes)')print('  GPU utilization: ~95%')print()print('=== Dynamic Batching ===')print('Group requests with similar lengths together')print('Minimize padding waste')print('Can combine with Continuous Batching for maximum efficiency')print()print('Implementation: vLLM, TGI, TensorRT-LLM all support continuous batching')
