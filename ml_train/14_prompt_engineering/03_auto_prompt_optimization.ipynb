# %% [markdown]
# # 14.3 自动提示优化本节涵盖：APE, DSPy, OPRO

# %%
print('=== APE (Automatic Prompt Engineer) ===')print('1. Use LLM to generate candidate prompts')print('2. Evaluate each prompt on validation set')print('3. Select best performing prompt')print()print('Example:')print('  Task: Sentiment classification')print('  Generated prompts:')print('    - "Classify the sentiment:"')print('    - "Is this text positive or negative?"')print('    - "Analyze the emotional tone:"')print('  Evaluate on 100 examples -> select best')print()print('=== DSPy ===')print('Programming framework for prompt optimization')print()print('Steps:')print('  1. Define Signature: input/output specification')print('  2. Define Module: ChainOfThought, ReAct, etc.')print('  3. Define Metric: evaluation function')print('  4. Optimize: BootstrapFewShot, MIPRO, etc.')print()print('Example:')print('  class EmotionSignatures(dspy.Signature):')print('      """Classify emotion in text."""')print('      text = dspy.InputDesc()')print('      emotion = dspy.OutputDesc()')print()print('=== OPRO (Optimization by PROmpting) ===')print('Use LLM as optimizer for prompts')print('1. Give LLM history of prompts and their scores')print('2. LLM generates improved prompt')print('3. Evaluate new prompt, add to history')print('4. Iterate until convergence')print()print('Key insight: LLMs can improve their own prompts through reflection')
