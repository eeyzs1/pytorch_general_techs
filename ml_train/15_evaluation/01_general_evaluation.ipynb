# %% [markdown]
# # 15.1 通用能力评估本节涵盖：MMLU, HellaSwag, ARC, C-Eval

# %%
print('=== General Capability Benchmarks ===')print()print('MMLU (Massive Multitask Language Understanding):')print('  - 57 subjects: STEM, humanities, social sciences, etc.')print('  - Multiple choice questions')print('  - Tests breadth of knowledge')print('  - GPT-4: ~86%, LLaMA-3-70B: ~82%, Mistral-7B: ~62%')print()print('HellaSwag:')print('  - Commonsense reasoning: predict next event')print('  - Adversarial: wrong options from similar contexts')print('  - Tests: situational understanding, common sense')print()print('ARC (AI2 Reasoning Challenge):')print('  - Science questions from grade 3-9')print('  - ARC-Easy and ARC-Challenge splits')print('  - Tests: scientific reasoning')print()print('C-Eval / CMMLU:')print('  - Chinese multi-subject evaluation')print('  - 52+ subjects covering Chinese curriculum')print('  - Essential for Chinese LLM evaluation')print()print('=== Running Evaluations with lm-eval-harness ===')print('pip install lm-eval')print('lm_eval --model hf --model_args pretrained=meta-llama/Llama-2-7b --tasks mmlu,hellaswag')
