# %% [markdown]
# # 15.3 数学能力评估本节涵盖：GSM8K, MATH

# %%
print('=== Math Reasoning Benchmarks ===')print()print('GSM8K (Grade School Math 8K):')print('  - 8,500 grade school math word problems')print('  - Requires multi-step arithmetic reasoning')print('  - Metric: final answer accuracy')print('  - GPT-4: 92%, LLaMA-3-70B: 85%, Mistral-7B: 52%')print()print('Example GSM8K problem:')print('  "Janet\'s ducks lay 16 eggs per day. She eats three for breakfast')print('   every morning and bakes muffins for her friends every day with four.')print('   She sells the remainder at the farmers\' market daily for $2 each."')print('  Question: How much does she make every day at the farmers\' market?')print('  Answer: 16 - 3 - 4 = 9 eggs. 9 * $2 = $18')print()print('MATH dataset:')print('  - Competition-level math problems')print('  - 7,500 problems across 7 categories')print('  - Much harder than GSM8K')print('  - Categories: Algebra, Counting & Probability, Geometry,')print('    Intermediate Algebra, Number Theory, Prealgebra, Precalculus')print('  - GPT-4: 52%, much lower than GSM8K showing difficulty gap')print()print('CoT prompting significantly improves math performance.')
