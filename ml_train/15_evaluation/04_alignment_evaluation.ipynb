# %% [markdown]
# # 15.4 对齐评估本节涵盖：AlpacaEval, MT-Bench, Arena Elo

# %%
print('=== Alignment Evaluation Benchmarks ===')print()print('AlpacaEval:')print('  - LLM-as-judge evaluation framework')print('  - Compare model output vs reference (GPT-4/ChatGPT)')print('  - Metric: win rate against reference')print('  - Fast, cheap, correlates well with human judgment')print('  - AlpacaEval 2.0: length-controlled win rates')print()print('MT-Bench:')print('  - Multi-turn conversation benchmark')print('  - 80 questions across 8 categories:')print('    writing, roleplay, reasoning, math, coding, extraction, STEM, humanities')print('  - LLM judge scores on 1-10 scale')print('  - Two-turn conversations to test follow-up ability')print()print('Chatbot Arena (Arena Elo):')print('  - Human preference-based evaluation')print('  - Users chat with two anonymous models, vote preference')print('  - Elo rating system (like chess)')print('  - Most reliable real-world evaluation')print('  - Leaderboard: chat.lmsys.org')print()print('=== Evaluation Pipeline ===')print('1. Generate responses for all test prompts')print('2. Use GPT-4 as judge: compare pairs of responses')print('3. Compute win rates and Elo scores')print('4. Correlate with human preference studies')
