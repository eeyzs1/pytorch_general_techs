# %% [markdown]
# # 15.2 代码能力评估本节涵盖：HumanEval, MBPP, SWE-bench

# %%
print('=== Code Generation Benchmarks ===')print()print('HumanEval:')print('  - 164 Python programming problems')print('  - Given function signature + docstring, generate implementation')print('  - Metric: Pass@k (probability at least 1 of k samples passes unit tests)')print('  - GPT-4: Pass@1=67%, DeepSeek-Coder-33B: Pass@1=55%')print()print('MBPP (Mostly Basic Python Problems):')print('  - 974 entry-level Python tasks')print('  - Simpler than HumanEval')print('  - Tests basic programming competence')print()print('SWE-bench:')print('  - Real GitHub issues from popular Python repos')print('  - Model must generate patch to fix the issue')print('  - Evaluated on actual test suites')print('  - Tests: real-world software engineering ability')print('  - SWE-bench Lite: 300 problems, SWE-bench Full: 2294')print()print('=== Evaluation Example ===')print('"""')def has_close_elements(numbers, threshold):    """Check if two numbers in the list are closer than threshold."""    # Model generates this implementation    for i in range(len(numbers)):        for j in range(i+1, len(numbers)):            if abs(numbers[i] - numbers[j]) < threshold:                return True    return False# Unit test: assert has_close_elements([1.0, 2.0, 3.0], 0.5) == False# Unit test: assert has_close_elements([1.0, 2.8, 3.0, 4.0, 5.0, 2.0], 0.3) == True'"""')
